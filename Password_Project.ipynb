# %% [markdown]
# <a href="https://colab.research.google.com/github/Awaleena/Awadh-the-coder/blob/main/Password_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Password Manager

# Store password (initially None)
stored_password = None

def create_password():
    global stored_password
    password = input("Create a new password: ")
    confirm = input("Confirm your password: ")

    if password == confirm:
        stored_password = password
        print("✅ Password created successfully!")
    else:
        print("❌ Passwords do not match. Try again.")

def change_password():
    global stored_password

    if stored_password is None:
        print("⚠️ No password set. Please create one first.")
        return

    old_password = input("Enter current password: ")

    if old_password == stored_password:
        new_password = input("Enter new password: ")
        confirm = input("Confirm new password: ")

        if new_password == confirm:
            stored_password = new_password
            print("✅ Password changed successfully!")
        else:
            print("❌ New passwords do not match.")
    else:
        print("❌ Incorrect current password.")

def menu():
    while True:
        print("\n--- Password Manager ---")
        print("1. Create Password")
        print("2. Change Password")
        print("3. Exit")

        choice = input("Enter your choice: ")

        if choice == '1':
            create_password()
        elif choice == '2':
            change_password()
        elif choice == '3':
            print("Goodbye!")
            break
        else:
            print("❌ Invalid choice. Try again.")

# Run program
menu()
# Out:
# --- Password Manager ---
# 1. Create Password
# 2. Change Password
# 3. Exit
# Enter your choice: 2
# ⚠️ No password set. Please create one first.
#
# --- Password Manager ---
# 1. Create Password
# 2. Change Password
# 3. Exit
# Enter your choice: 3
# Goodbye!
