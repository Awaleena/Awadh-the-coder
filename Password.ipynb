# %% [markdown]
# <a href="https://colab.research.google.com/github/Awaleena/Awadh-the-coder/blob/main/Password.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2

# %%
import PyPDF2

def encrypt_pdf(input_path, output_path, password):
    pdf_reader = PyPDF2.PdfReader(input_path)
    pdf_writer = PyPDF2.PdfWriter()

    for page_num in range(len(pdf_reader.pages)):
        pdf_writer.add_page(pdf_reader.pages[page_num])

    pdf_writer.encrypt(password)
    with open(output_path, 'wb') as out:
        pdf_writer.write(out)

    print(f"Encrypted PDF file is saved as: {output_path}")

encrypt_pdf('Guitar.pdf','pass.pdf','#Awalin2')
# Out:
# Encrypted PDF file is saved as: pass.pdf
